# %%
pip install gradio pillow
# Out:
# Collecting gradio
#   Downloading gradio-6.1.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: pillow in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (12.0.0)
# Collecting aiofiles<25.0,>=22.0 (from gradio)
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting anyio<5.0,>=3.0 (from gradio)
#   Downloading anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting brotli>=1.1.0 (from gradio)
#   Downloading brotli-1.2.0-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio)
#   Downloading fastapi-0.124.2-py3-none-any.whl.metadata (30 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-1.0.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting gradio-client==2.0.1 (from gradio)
#   Downloading gradio_client-2.0.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio)
#   Using cached groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting httpx<1.0,>=0.24.1 (from gradio)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from gradio) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from gradio) (2.2.6)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.11.5-cp312-cp312-win_amd64.whl.metadata (42 kB)
# Requirement already satisfied: packaging in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from gradio) (25.0)
# Collecting pandas<3.0,>=1.0 (from gradio)
#   Downloading pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting pydantic<=2.12.4,>=2.11.10 (from gradio)
#   Downloading pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
# Collecting pydub (from gradio)
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio)
#   Using cached python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from gradio) (6.0.3)
# Collecting safehttpx<0.2.0,>=0.1.7 (from gradio)
#   Downloading safehttpx-0.1.7-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio)
#   Downloading starlette-0.50.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio)
#   Downloading tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting typer<1.0,>=0.12 (from gradio)
#   Downloading typer-0.20.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from gradio) (4.15.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: fsspec in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from gradio-client==2.0.1->gradio) (2025.12.0)
# Requirement already satisfied: idna>=2.8 in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from anyio<5.0,>=3.0->gradio) (3.11)
# Collecting annotated-doc>=0.0.2 (from fastapi<1.0,>=0.115.2->gradio)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: certifi in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.11.12)
# Collecting httpcore==1.* (from httpx<1.0,>=0.24.1->gradio)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: filelock in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.0)
# Requirement already satisfied: requests in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas<3.0,>=1.0->gradio)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3.0,>=1.0->gradio)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<=2.12.4,>=2.11.10->gradio)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<=2.12.4,>=2.11.10->gradio)
#   Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<=2.12.4,>=2.11.10->gradio)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: click>=8.0.0 in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from typer<1.0,>=0.12->gradio) (8.1.8)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0,>=0.12->gradio)
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: colorama in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from click>=8.0.0->typer<1.0,>=0.12->gradio) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alexp\anaconda3\envs\ipm2\lib\site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (2.6.1)
# Downloading gradio-6.1.0-py3-none-any.whl (23.0 MB)
#    ---------------------------------------- 0.0/23.0 MB ? eta -:--:--
#    - -------------------------------------- 1.0/23.0 MB 6.3 MB/s eta 0:00:04
#    ------ --------------------------------- 3.7/23.0 MB 9.9 MB/s eta 0:00:02
#    --------- ------------------------------ 5.5/23.0 MB 10.2 MB/s eta 0:00:02
#    ------------- -------------------------- 7.9/23.0 MB 9.5 MB/s eta 0:00:02
#    ------------------ --------------------- 10.5/23.0 MB 10.4 MB/s eta 0:00:02
#    --------------------- ------------------ 12.6/23.0 MB 10.2 MB/s eta 0:00:02
#    -------------------------- ------------- 15.5/23.0 MB 10.6 MB/s eta 0:00:01
#    ------------------------------- -------- 18.4/23.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------- -- 21.8/23.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  22.8/23.0 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 23.0/23.0 MB 11.0 MB/s  0:00:02
# Downloading gradio_client-2.0.1-py3-none-any.whl (55 kB)
# Using cached aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
# Downloading fastapi-0.124.2-py3-none-any.whl (112 kB)
# Using cached groovy-0.1.2-py3-none-any.whl (14 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading orjson-3.11.5-cp312-cp312-win_amd64.whl (133 kB)
# Downloading pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/11.0 MB 6.7 MB/s eta 0:00:02
#    --------------- ------------------------ 4.2/11.0 MB 10.1 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.0 MB 11.5 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.0 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 10.4 MB/s  0:00:01
# Downloading pydantic-2.12.4-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------------- -------- 1.6/2.0 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 12.6 MB/s  0:00:00
# Downloading safehttpx-0.1.7-py3-none-any.whl (9.0 kB)
# Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
# Downloading tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Downloading typer-0.20.0-py3-none-any.whl (47 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading brotli-1.2.0-cp312-cp312-win_amd64.whl (369 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Downloading ffmpy-1.0.0-py3-none-any.whl (5.6 kB)
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pytz, pydub, brotli, tzdata, typing-inspection, tomlkit, shellingham, semantic-version, python-multipart, pydantic-core, orjson, mdurl, h11, groovy, ffmpy, anyio, annotated-types, annotated-doc, aiofiles, uvicorn, starlette, pydantic, pandas, markdown-it-py, httpcore, rich, httpx, fastapi, typer, safehttpx, gradio-client, gradio
#
#    ----------------------------------------  0/32 [pytz]
#    ----------------------------------------  0/32 [pytz]
#    ----------------------------------------  0/32 [pytz]
#    --- ------------------------------------  3/32 [tzdata]
#    --- ------------------------------------  3/32 [tzdata]
#    --- ------------------------------------  3/32 [tzdata]
#    ------ ---------------------------------  5/32 [tomlkit]
#    ---------- -----------------------------  8/32 [python-multipart]
#    --------------- ------------------------ 12/32 [h11]
#    ------------------ --------------------- 15/32 [anyio]
#    -------------------- ------------------- 16/32 [annotated-types]
#    ----------------------- ---------------- 19/32 [uvicorn]
#    ------------------------- -------------- 20/32 [starlette]
#    -------------------------- ------------- 21/32 [pydantic]
#    -------------------------- ------------- 21/32 [pydantic]
#    -------------------------- ------------- 21/32 [pydantic]
#    -------------------------- ------------- 21/32 [pydantic]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    --------------------------- ------------ 22/32 [pandas]
#    ---------------------------- ----------- 23/32 [markdown-it-py]
#    ---------------------------- ----------- 23/32 [markdown-it-py]
#    ------------------------------ --------- 24/32 [httpcore]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    ------------------------------- -------- 25/32 [rich]
#    --------------------------------- ------ 27/32 [fastapi]
#    --------------------------------- ------ 27/32 [fastapi]
#    ------------------------------------- -- 30/32 [gradio-client]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    -------------------------------------- - 31/32 [gradio]
#    ---------------------------------------- 32/32 [gradio]
#
# Successfully installed aiofiles-24.1.0 annotated-doc-0.0.4 annotated-types-0.7.0 anyio-4.12.0 brotli-1.2.0 fastapi-0.124.2 ffmpy-1.0.0 gradio-6.1.0 gradio-client-2.0.1 groovy-0.1.2 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 markdown-it-py-4.0.0 mdurl-0.1.2 orjson-3.11.5 pandas-2.3.3 pydantic-2.12.4 pydantic-core-2.41.5 pydub-0.25.1 python-multipart-0.0.20 pytz-2025.2 rich-14.2.0 safehttpx-0.1.7 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.50.0 tomlkit-0.13.3 typer-0.20.0 typing-inspection-0.4.2 tzdata-2025.2 uvicorn-0.38.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import gradio as gr
import cv2
import numpy as np
import time
from PIL import Image as PILImage
from ultralytics import YOLO
from transformers import CLIPProcessor, CLIPModel
from gtts import gTTS 
import random
import os

# --- LÓGICA DEL SISTEMA (BACKEND) ---
class GymkhanaMaster:
    def __init__(self):
        print("🛠️ System Init: Cargando Modelos Neurales...")
        self.yolo = YOLO('yolov8n.pt')
        self.clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
        self.clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
        self.current_target = None
        self.time_limit = 60
        self.start_time = 0
        self.game_active = False
        self.modo_historia = "Agente Especial"

    def _hablar(self, texto):
        tts = gTTS(text=texto, lang='es')
        filename = "audio_temp.mp3"
        tts.save(filename)
        return filename

    def configurar_partida(self, dificultad, modo):
        tiempos = {"🟢 Recluta (60s)": 60, "🟡 Veterano (30s)": 30, "🔴 Élite (15s)": 15}
        self.time_limit = tiempos.get(dificultad, 60)
        self.modo_historia = modo
        return self.time_limit

    def generar_narrativa(self, objeto):
        """Genera HTML visual y texto de voz"""
        obj_upper = objeto.upper()
        
        # Icono según modo
        icono = "🎯"
        if "Zombie" in self.modo_historia: icono = "🧟"
        elif "Espía" in self.modo_historia: icono = "🕵️‍♂️"

        # Texto para el audio (Voz)
        if "Zombie" in self.modo_historia:
            voz = f"Superviviente. Necesitas un {objeto}. Tienes {self.time_limit} segundos."
            subtitulo = "⚠️ SUMINISTRO VITAL REQUERIDO"
        elif "Espía" in self.modo_historia:
            voz = f"Agente. Intercepte el {objeto} inmediatamente."
            subtitulo = "📁 MISIÓN CLASIFICADA: RECUPERACIÓN"
        else:
            voz = f"Encuentra un {objeto}. Tiempo corriendo."
            subtitulo = "🎯 OPERACIÓN ESTÁNDAR"

        # HTML PARA LA PANTALLA (VISUAL GIGANTE)
        html_visual = f"""
        <div class="hud-box">
            <div class="hud-sub">{icono} {subtitulo}</div>
            <div class="hud-target">{obj_upper}</div>
            <div class="hud-desc">Localice y asegure el objetivo antes de que acabe el tiempo.</div>
        </div>
        """
        
        return html_visual, voz

    def estampar_sello(self, imagen_numpy, texto_sello, es_victoria=True):
        img = imagen_numpy.copy()
        h, w = img.shape[:2]
        overlay = img.copy()
        color = (0, 255, 0) if es_victoria else (255, 0, 0)
        texto_sello = texto_sello.upper()
        font = cv2.FONT_HERSHEY_DUPLEX
        scale = 1.0 if w < 400 else 2.5
        thickness = 2 if w < 400 else 5
        (tw, th), _ = cv2.getTextSize(texto_sello, font, scale, thickness)
        cx, cy = w // 2, h // 2
        cv2.rectangle(overlay, (cx - tw//2 - 20, cy - th - 20), (cx + tw//2 + 20, cy + 20), color, thickness)
        cv2.putText(overlay, texto_sello, (cx - tw//2, cy), font, scale, color, thickness)
        alpha = 0.8
        cv2.addWeighted(overlay, alpha, img, 1 - alpha, 0, img)
        return img

    def escanear_sala(self, imagen_sala):
        if imagen_sala is None: 
            return '<div class="hud-box-empty">ESPERANDO ESCANEO...</div>', None, None
        
        pil_img = PILImage.fromarray(imagen_sala)
        cv_img = cv2.cvtColor(np.array(pil_img), cv2.COLOR_RGB2BGR)
        res = self.yolo(cv_img, conf=0.25, verbose=False)[0]
        objs = list(set([self.yolo.names[int(b.cls[0])] for b in res.boxes]))
        
        if not objs: 
            return '<div class="hud-box-error">⚠️ NO SE DETECTAN OBJETIVOS</div>', None, None

        self.current_target = random.choice(objs)
        self.start_time = time.time()
        self.game_active = True
        
        html_mision, txt_voz = self.generar_narrativa(self.current_target)
        audio = self._hablar(txt_voz)
        
        html_barra = f"""
        <div class="timer-container">
            <div class="timer-bar" style="animation-duration: {self.time_limit}s;"></div>
            <div class="timer-text">TIEMPO RESTANTE</div>
        </div>
        """
        return html_mision, audio, html_barra

    def verificar_jugada(self, imagen_usuario):
        if not self.game_active: return "error", "SISTEMA INACTIVO", "Inicie escaneo.", None
        if imagen_usuario is None: return "error", "SIN SEÑAL", "Active cámara.", None

        pil_img = PILImage.fromarray(imagen_usuario)
        opciones = [f"a photo of a {self.current_target}", "something else"]
        inputs = self.clip_processor(text=opciones, images=pil_img, return_tensors="pt", padding=True)
        probs = self.clip_model(**inputs).logits_per_image.softmax(dim=1)
        
        if probs.argmax().item() == 0 and probs[0][0].item() > 0.6:
            self.game_active = False
            self._hablar("Objetivo confirmado. Misión cumplida.")
            img_final = self.estampar_sello(imagen_usuario, "CONFIRMADO", True)
            return "win", "MISIÓN CUMPLIDA", f"El activo '{self.current_target}' ha sido asegurado.", img_final
        else:
            self._hablar("Objetivo incorrecto.")
            return "retry", "ERROR DE IDENTIFICACIÓN", "El objeto no coincide.", None

    def check_tiempo(self):
        if self.game_active and (time.time() - self.start_time > self.time_limit):
            self.game_active = False
            self._hablar("Tiempo agotado. Operación cancelada.")
            return True
        return False

juego = GymkhanaMaster()

# --- DISEÑO VISUAL ---
css_tactical = """
@import url('https://fonts.googleapis.com/css2?family=Rajdhani:wght@500;700&display=swap');
body { background-color: #0f172a; color: #e2e8f0; font-family: 'Rajdhani', sans-serif; }
.gradio-container { max-width: 1000px !important; margin: auto; }

/* Paneles de Cristal */
.glass-panel {
    background: rgba(30, 41, 59, 0.7); backdrop-filter: blur(10px);
    border: 1px solid rgba(148, 163, 184, 0.2); border-radius: 15px; padding: 20px;
    box-shadow: 0 4px 6px -1px rgba(0, 0, 0, 0.5); margin-bottom: 15px;
}

/* --- ESTILO DEL HUD (OBJETIVO) --- */
.hud-box {
    text-align: center; border: 1px solid #3b82f6; 
    background: radial-gradient(circle, rgba(30,58,138,0.6) 0%, rgba(15,23,42,0.8) 100%);
    border-radius: 10px; padding: 15px;
    box-shadow: 0 0 15px rgba(59, 130, 246, 0.3);
}
.hud-box-empty { text-align: center; color: #64748b; padding: 20px; font-size: 1.5em; letter-spacing: 2px; }
.hud-box-error { text-align: center; color: #ef4444; padding: 20px; font-weight: bold; }
.hud-sub { color: #94a3b8; font-size: 0.9em; letter-spacing: 3px; margin-bottom: 5px; text-transform: uppercase; }
.hud-target { 
    font-size: 3.5em; font-weight: 700; color: #ffffff; 
    text-shadow: 0 0 20px #22d3ee; margin: 10px 0;
    text-transform: uppercase; letter-spacing: 2px;
}
.hud-desc { color: #cbd5e1; font-size: 1em; font-style: italic; }

.timer-container {
    width: 100%; height: 24px; background: #1e293b; border-radius: 12px; overflow: hidden; position: relative;
    border: 1px solid #334155; margin-top: 10px;
}
.timer-bar {
    height: 100%; background: linear-gradient(90deg, #22d3ee, #3b82f6);
    width: 0%; animation-name: countdown; animation-timing-function: linear; animation-fill-mode: forwards;
}
.timer-text { position: absolute; top: 0; width: 100%; text-align: center; line-height: 24px; color: white; font-size: 14px; font-weight: bold; text-shadow: 0 1px 2px black; }
@keyframes countdown { from { width: 100%; background: #22d3ee; } to { width: 0%; background: #ef4444; } }

.primary-btn { background: linear-gradient(135deg, #2563eb, #1d4ed8) !important; border: none; color: white; }
.scan-btn { background: #334155 !important; border: 1px solid #475569; color: #e2e8f0; }
.action-btn { background: linear-gradient(135deg, #dc2626, #b91c1c) !important; color: white; }
.feedback-error { color: #f87171; text-align: center; font-weight: bold; font-size: 1.2em; animation: shake 0.5s; }
@keyframes shake { 0% { transform: translate(1px, 1px); } 50% { transform: translate(-1px, -1px); } 100% { transform: translate(1px, 1px); } }
"""

# --- INTERFAZ ---
with gr.Blocks(theme=gr.themes.Soft(primary_hue="cyan", neutral_hue="slate"), css=css_tactical) as demo:
    
    timer = gr.Timer(1, active=False)
    
    # MENÚ
    with gr.Column(visible=True, elem_classes=["glass-panel"]) as p_menu:
        gr.Markdown("# 🛡️ GYMKHANA OPS", elem_classes=["main-title"])
        gr.Markdown("SISTEMA DE ENTRENAMIENTO DE INTELIGENCIA VISUAL", elem_classes=["sub-title"])
        with gr.Row():
            sel_dif = gr.Radio(["🟢 Recluta (60s)", "🟡 Veterano (30s)", "🔴 Élite (15s)"], label="DIFICULTAD", value="🟢 Recluta (60s)")
            sel_mod = gr.Radio(["🕵️ Agente Espía", "🧟 Superviviente Zombie", "🏠 Modo Estándar"], label="ESCENARIO", value="🕵️ Agente Espía")
        btn_start = gr.Button("INICIAR OPERACIÓN", variant="primary", elem_classes=["primary-btn"])

    # JUEGO
    with gr.Column(visible=False) as p_juego:
        
        # CABECERA HUD
        with gr.Row(elem_classes=["glass-panel"]):
            with gr.Column(scale=3):
                html_obj = gr.HTML(value='<div class="hud-box-empty">ESPERANDO DATOS DE MISIÓN...</div>')
            with gr.Column(scale=2):
                html_bar = gr.HTML() 

        # ZONA ACCIÓN
        with gr.Row():
            with gr.Column(elem_classes=["glass-panel"]):
                gr.Markdown("### 📡 1. INTELIGENCIA")
                # === HE ELIMINADO show_download_button AQUI ===
                in_sala = gr.Image(sources=["upload"], type="numpy", height=250, show_label=False)
                btn_scan = gr.Button("ANALIZAR ENTORNO", elem_classes=["scan-btn"])
            
            with gr.Column(elem_classes=["glass-panel"]):
                gr.Markdown("### 📸 2. CAMPO")
                # === HE ELIMINADO show_download_button AQUI ===
                in_cam = gr.Image(sources=["webcam"], type="numpy", height=250, show_label=False)
                btn_ok = gr.Button("CONFIRMAR OBJETIVO", elem_classes=["action-btn"])
        
        html_fb = gr.HTML(value='<div class="feedback-neutral">SISTEMA EN ESPERA...</div>', elem_classes=["glass-panel"])
        aud_out = gr.Audio(autoplay=True, visible=False)

    # FINAL
    with gr.Column(visible=False, elem_classes=["glass-panel"]) as p_final:
        gr.Markdown("# 📁 INFORME DE MISIÓN", elem_classes=["main-title"])
        # === HE ELIMINADO show_download_button AQUI ===
        img_result = gr.Image(show_label=False, interactive=False, height=400)
        lbl_res_titulo = gr.Markdown(elem_classes=["sub-title"])
        lbl_res_desc = gr.Markdown(elem_classes=["feedback-neutral"])
        btn_reset = gr.Button("NUEVA OPERACIÓN", variant="primary", elem_classes=["primary-btn"])

    # --- WIRING ---
    def start_game(d, m):
        juego.configurar_partida(d, m)
        return {
            p_menu: gr.Column(visible=False), p_juego: gr.Column(visible=True), p_final: gr.Column(visible=False),
            in_sala: None, in_cam: None, 
            html_obj: '<div class="hud-box-empty">SUBE UNA FOTO PARA RECIBIR ÓRDENES</div>', 
            html_bar: "", html_fb: "", timer: gr.Timer(active=False)
        }
    btn_start.click(start_game, [sel_dif, sel_mod], [p_menu, p_juego, p_final, in_sala, in_cam, html_obj, html_bar, html_fb, timer])

    def scan_room(img):
        h_mision, a, h_bar = juego.escanear_sala(img)
        feedback = '<div style="text-align:center; color:#22d3ee">¡OBJETIVO ASIGNADO!</div>' if h_bar else '<div class="feedback-error">ERROR DE IMAGEN</div>'
        return h_mision, a, h_bar, feedback, gr.Timer(active=bool(h_bar))
    btn_scan.click(scan_room, in_sala, [html_obj, aud_out, html_bar, html_fb, timer])

    def verify_obj(img):
        res, tit, msg, final_img = juego.verificar_jugada(img)
        if res == "retry":
            return {html_fb: f'<div class="feedback-error">{msg}</div>'}
        else:
            return {
                p_juego: gr.Column(visible=False), p_final: gr.Column(visible=True),
                img_result: final_img, lbl_res_titulo: f"## {tit}", lbl_res_desc: msg,
                timer: gr.Timer(active=False)
            }
    btn_ok.click(verify_obj, in_cam, [html_fb, p_juego, p_final, img_result, lbl_res_titulo, lbl_res_desc, timer])

    def time_check():
        if juego.check_tiempo():
            black_img = np.zeros((400, 600, 3), dtype=np.uint8)
            fail_img = juego.estampar_sello(black_img, "MISION FALLIDA", False)
            return {
                p_juego: gr.Column(visible=False), p_final: gr.Column(visible=True),
                img_result: fail_img, lbl_res_titulo: "## TIEMPO AGOTADO", lbl_res_desc: "El objetivo se ha perdido.",
                timer: gr.Timer(active=False)
            }
        return gr.update()
    timer.tick(time_check, outputs=[p_juego, p_final, img_result, lbl_res_titulo, lbl_res_desc, timer])
    btn_reset.click(lambda: {p_menu: gr.Column(visible=True), p_final: gr.Column(visible=False)}, outputs=[p_menu, p_final])

demo.launch(share=True)
# Out:
# 🛠️ System Init: Cargando Modelos Neurales...
# C:\Users\alexp\AppData\Local\Temp\ipykernel_11404\2239237329.py:188: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: theme, css. Please pass these parameters to launch() instead.
#   with gr.Blocks(theme=gr.themes.Soft(primary_hue="cyan", neutral_hue="slate"), css=css_tactical) as demo:
# * Running on local URL:  http://127.0.0.1:7868
# * Running on public URL: https://edfec36f11a6183f3c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://edfec36f11a6183f3c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\uvicorn\protocols\http\h11_impl.py", line 403, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\uvicorn\middleware\proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\fastapi\applications.py", line 1139, in __call__
#     await super().__call__(scope, receive, send)
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\starlette\applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\starlette\middleware\errors.py", line 186, in __call__
#     raise exc
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\starlette\middleware\errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\gradio\brotli_middleware.py", line 74, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\gradio\route_utils.py", line 882, in __call__
#     await self.app(scope, receive, send)
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\starlette\middleware\exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\fastapi\middleware\asyncexitstack.py", line 18, in __call__
#     await self.app(scope, receive, send)
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\starlette\routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\starlette\routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\starlette\routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\fastapi\routing.py", line 120, in app
#     await wrap_app_handling_exceptions(app, request)(scope, receive, send)
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\starlette\_exception_handler.py", line 53, in wrapped_app
#     raise exc
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\starlette\_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\fastapi\routing.py", line 106, in app
#     response = await f(request)
#                ^^^^^^^^^^^^^^^^
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\fastapi\routing.py", line 430, in app
#     raw_response = await run_endpoint_function(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\fastapi\routing.py", line 316, in run_endpoint_function
#     return await dependant.call(**values)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\gradio\routes.py", line 1679, in get_upload_progress
#     await asyncio.wait_for(
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\asyncio\tasks.py", line 520, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\site-packages\gradio\route_utils.py", line 528, in is_tracked
#     return await self._signals[upload_id].wait()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\asyncio\locks.py", line 209, in wait
#     fut = self._get_loop().create_future()
#           ^^^^^^^^^^^^^^^^
#   File "c:\Users\alexp\anaconda3\envs\IPM2\Lib\asyncio\mixins.py", line 20, in _get_loop
#     raise RuntimeError(f'{self!r} is bound to a different event loop')
# RuntimeError: <asyncio.locks.Event object at 0x000001AD23C806B0 [unset]> is bound to a different event loop
